# %%
import requests
import urllib.request 
from urllib.request import urlopen 
from bs4 import BeautifulSoup
import re
import json
import pandas as pd
import numpy as np
from numpy.random import randint 
from datetime import date
import datetime as dt
import os 
import glob

# %%
rootpage = 'https://www.rottentomatoes.com/sitemap_' 
end = '.xml'
today = date.today()

def getLinks(pageUrl):
    global pages 
    for sitemap_page in range(0, 25): 
        pages = set() 
        html = urlopen(rootpage+str(sitemap_page)+end)
        bsObj = BeautifulSoup(html)
        
        for link in bsObj.findAll('loc'):
            replacers = ['trailers/', 'pictures/']
            link = str(link).replace('</loc>', '').split('.com')
            
            if link[1] not in pages: 
                pages.add(link[1])
    
        pages = pd.DataFrame(pages, columns=['links'])
        pages.to_csv(r'/Users/mimiyufanyou/Documents/GitHub/rotten_movies/data/movie_links/links_'+str(today)+'_'+str(sitemap_page)+'.csv', sep=',')
        
        print('saved to csv:','links_'+str(today)+'_'+str(sitemap_page)+'.csv', dt.datetime.now())

getLinks('')
# Out:
# saved to csv: links_2019-11-17_0.csv 2019-11-17 11:23:10.668879
# saved to csv: links_2019-11-17_1.csv 2019-11-17 11:23:12.585492
# saved to csv: links_2019-11-17_2.csv 2019-11-17 11:23:14.708517
# saved to csv: links_2019-11-17_3.csv 2019-11-17 11:23:16.476187
# saved to csv: links_2019-11-17_4.csv 2019-11-17 11:23:18.533097
# saved to csv: links_2019-11-17_5.csv 2019-11-17 11:23:20.885766
# saved to csv: links_2019-11-17_6.csv 2019-11-17 11:23:22.924453
# saved to csv: links_2019-11-17_7.csv 2019-11-17 11:23:27.338525
# saved to csv: links_2019-11-17_8.csv 2019-11-17 11:23:29.358984
# saved to csv: links_2019-11-17_9.csv 2019-11-17 11:23:31.620002
# saved to csv: links_2019-11-17_10.csv 2019-11-17 11:23:33.581253
# saved to csv: links_2019-11-17_11.csv 2019-11-17 11:23:39.416555
# saved to csv: links_2019-11-17_12.csv 2019-11-17 11:23:41.574564
# saved to csv: links_2019-11-17_13.csv 2019-11-17 11:23:43.869375
# saved to csv: links_2019-11-17_14.csv 2019-11-17 11:23:46.269565
# saved to csv: links_2019-11-17_15.csv 2019-11-17 11:23:48.887388
# saved to csv: links_2019-11-17_16.csv 2019-11-17 11:23:51.298292
# saved to csv: links_2019-11-17_17.csv 2019-11-17 11:23:53.305965
# saved to csv: links_2019-11-17_18.csv 2019-11-17 11:23:56.876087
# saved to csv: links_2019-11-17_19.csv 2019-11-17 11:24:00.876007
# saved to csv: links_2019-11-17_20.csv 2019-11-17 11:24:02.760074
# saved to csv: links_2019-11-17_21.csv 2019-11-17 11:24:04.577785
# saved to csv: links_2019-11-17_22.csv 2019-11-17 11:24:06.655135
# saved to csv: links_2019-11-17_23.csv 2019-11-17 11:24:10.359020
# saved to csv: links_2019-11-17_24.csv 2019-11-17 11:24:11.831567

# %%
filepath = r'/Users/mimiyufanyou/Documents/GitHub/rotten_movies/data/movie_links/*.csv'
df_links = pd.concat([pd.read_csv(f) for f in glob.glob(filepath)], ignore_index = True)
df_links = list(df_links['links'])

# %%
trimmed_links = set()

for links in df_links:
    links = links.replace('/pictures/', '').replace('/trailers/', '') 
    trimmed_links.add(links)

df_links = pd.DataFrame(df_links)

# %%
baseurl = 'https://www.rottentomatoes.com'
listlength = len(trimmed_links)
movie_df = pd.DataFrame(columns=['url', 'title', 'tomatoScore', 'popcornScore'])
today = date.today()

def getScores(link):
    try: 
        siteurl = urlopen(baseurl+link)

        bsObj = BeautifulSoup(siteurl)
        movie_title = str(bsObj).split('"name":"')[1].split('"')[0]
        #print(movie_title)

        tomatoScore = str(bsObj).split('ratingValue":')[1].split(',"')[0]
        #print(tomatoScore)

        ems_id = str(bsObj).split('emsId":"')[1].split('"')[0]
        ems_req_url = f'https://www.rottentomatoes.com/napi/audienceScore/{ems_id}'

        ems_response = requests.get(ems_req_url)
        ems_soup = BeautifulSoup(ems_response.text, 'html.parser')
        ems_text_response = ems_response.text
        json_ems = json.loads(ems_text_response)
        popcornScore = json_ems['audienceScoreAll']['score']
        #print(popcornScore)

        movie_df.loc[link] = [link, movie_title, tomatoScore, popcornScore]
    except: 
        pass

# %%
df_links
# Out:
#                                        0
# 0                  /m/1018440-sea_wolves
# 1                             /m/message
# 2                    /m/mickey_blue_eyes
# 3             /m/prozac-nation/trailers/
# 4                     /m/1069707-othello
# ...                                  ...
# 196567       /m/musical_chairs/trailers/
# 196568  /m/computer_chess_2013/pictures/
# 196569              /m/things_never_said
# 196570     /m/hello_i_must_be_going_2012
# 196571      /m/code_black_2014/pictures/
#
# [196572 rows x 1 columns]

# %%
for batch in range(19000,19050):
    for link in df_links.iloc[batch]: 
        movie_name = df_links.iloc[batch][0]
        getScores(movie_name)

movie_df.to_csv(r'/Users/mimiyufanyou/Documents/GitHub/rotten_movies/data/movie_scores/scores_'+str(today)+'_'+str(batch)+'.csv', sep=',')
print('saved to csv:','scores_'+str(today)+'_'+str(batch)+'.csv', dt.datetime.now())
# Out:
# saved to csv: scores_2019-11-17_19049.csv 2019-11-17 20:35:32.488106

# %%
filepath = r'/Users/mimiyufanyou/Documents/GitHub/rotten_movies/data/movie_scores/*.csv'
df_scores = pd.concat([pd.read_csv(f) for f in glob.glob(filepath)], ignore_index = True)
today = date.today()

df_scores = df_scores[['url', 'title', 'tomatoScore', 'popcornScore']]
df_scores['abs_squidScore'] = abs(df_scores['tomatoScore']- df_scores['popcornScore'])

df_final = df_scores[['url', 'title', 'tomatoScore', 'popcornScore', 'abs_squidScore']].dropna(how='any')

# %%
df_final['tScore_qcut'] = pd.qcut(df_final['tomatoScore'], 5, labels=False)
df_final['pScore_qcut'] = pd.qcut(df_final['popcornScore'], 5, labels=False)
df_final['sScore_qcut'] = pd.qcut(df_final['abs_squidScore'], 5, labels=False)

df_final['tScore_rnd'] = df_final['tomatoScore'].apply(lambda x: str(x)[0])
df_final['pScore_rnd'] = df_final['popcornScore'].apply(lambda x: str(x)[0])
df_final['sScore_rnd'] = df_final['abs_squidScore'].apply(lambda x: str(x)[0])

# %%
df_final
# Out:
#                                         url  \
# 2                       /m/mickey_blue_eyes
# 3                                 /m/clerks
# 4                                /m/schlock
# 5                        /m/amos_and_andrew
# 6                             /m/monkeybone
# 8                                /m/sssssss
# 11                          /m/1004502-coma
# 13                                /m/greedy
# 14                         /m/cactus_flower
# 16                    /m/leave_it_to_beaver
# 17                          /m/white-nights
# 20                    /m/1032980-diabolique
# 21                        /m/reindeer_games
# 23                     /m/1099622-innocents
# 24                 /m/bringing_out_the_dead
# 27                             /m/dead_bang
# 28                  /m/i_spit_on_your_grave
# 30                           /m/spider_baby
# 34                     /m/black_moon_rising
# 35                     /m/generals_daughter
# 36  /m/the_witch_who_came_from_the_sea_1976
# 37               /m/1009426-heaven_can_wait
# 38                             /m/carnosaur
# 41                      /m/mickey_blue_eyes
# 42                       /m/amos_and_andrew
# 43                            /m/monkeybone
# 45                               /m/sssssss
# 48                          /m/1004502-coma
# 50                                /m/greedy
# 51                         /m/cactus_flower
# 53                    /m/leave_it_to_beaver
# 54                          /m/white-nights
# 58                      /m/mickey_blue_eyes
# 59                                /m/clerks
# 60                               /m/schlock
# 61                       /m/amos_and_andrew
# 62                            /m/monkeybone
# 64                               /m/sssssss
# 67                          /m/1004502-coma
# 69                                /m/greedy
# 70                         /m/cactus_flower
# 72                    /m/leave_it_to_beaver
# 73                          /m/white-nights
# 75                    /m/1002497-black_hole
# 76                         /m/wild_at_heart
# 78                           /m/devils_rain
# 79                            /m/blue_crush
# 80                       /m/1037649-my_girl
# 81                         /m/lady_in_white
# 82                           /m/gone_fishin
# 83                          /m/jackie_brown
# 84                   /m/bigger_than_the_sky
# 85                        /m/sophies_choice
# 87                  /m/1107863-moulin_rouge
#
#                                       title  tomatoScore  popcornScore  \
# 2                          Mickey Blue Eyes         45.0            42
# 3                                    Clerks         88.0            89
# 4                                   Schlock         67.0            42
# 5                             Amos & Andrew         20.0            31
# 6                                Monkeybone         19.0            27
# 8                                   Sssssss         30.0            25
# 11                                     Coma         80.0            66
# 13                                   Greedy         28.0            48
# 14                            Cactus Flower         88.0            80
# 16                       Leave It to Beaver         21.0            32
# 17                             White Nights         46.0            75
# 20             Diabolique (Les Diaboliques)         95.0            93
# 21               Reindeer Games (Deception)         25.0            27
# 23                            The Innocents         94.0            86
# 24                    Bringing Out the Dead         72.0            70
# 27                                Dead Bang         33.0            43
# 28  I Spit on Your Grave (Day of the Woman)         53.0            40
# 30                              Spider Baby         92.0            76
# 34                        Black Moon Rising         38.0            24
# 35                   The General's Daughter         22.0            46
# 36          The Witch Who Came from the Sea         78.0            35
# 37                          Heaven Can Wait         85.0            76
# 38                                Carnosaur         11.0            23
# 41                         Mickey Blue Eyes         45.0            42
# 42                            Amos & Andrew         20.0            31
# 43                               Monkeybone         19.0            27
# 45                                  Sssssss         30.0            25
# 48                                     Coma         80.0            66
# 50                                   Greedy         28.0            48
# 51                            Cactus Flower         88.0            80
# 53                       Leave It to Beaver         21.0            32
# 54                             White Nights         46.0            75
# 58                         Mickey Blue Eyes         45.0            42
# 59                                   Clerks         88.0            89
# 60                                  Schlock         67.0            42
# 61                            Amos & Andrew         20.0            31
# 62                               Monkeybone         19.0            27
# 64                                  Sssssss         30.0            25
# 67                                     Coma         80.0            66
# 69                                   Greedy         28.0            48
# 70                            Cactus Flower         88.0            80
# 72                       Leave It to Beaver         21.0            32
# 73                             White Nights         46.0            75
# 75                           The Black Hole         40.0            45
# 76                            Wild At Heart         65.0            81
# 78                         The Devil's Rain         18.0            35
# 79                               Blue Crush         61.0            58
# 80                                  My Girl         53.0            77
# 81                            Lady in White         67.0            69
# 82                             Gone Fishin'          4.0            37
# 83                             Jackie Brown         87.0            85
# 84                      Bigger Than the Sky         12.0            53
# 85                          Sophie's Choice         76.0            85
# 87                            Moulin Rouge!         76.0            89
#
#     abs_squidScore  tScore_qcut  pScore_qcut  sScore_qcut tScore_rnd  \
# 2              3.0            2            1            0          4
# 3              1.0            4            4            0          8
# 4             25.0            3            1            4          6
# 5             11.0            0            0            2          2
# 6              8.0            0            0            1          1
# 8              5.0            1            0            1          3
# 11            14.0            3            3            3          8
# 13            20.0            1            2            3          2
# 14             8.0            4            4            1          8
# 16            11.0            0            1            2          2
# 17            29.0            2            3            4          4
# 20             2.0            4            4            0          9
# 21             2.0            1            0            0          2
# 23             8.0            4            4            1          9
# 24             2.0            3            3            0          7
# 27            10.0            1            2            2          3
# 28            13.0            2            1            3          5
# 30            16.0            4            3            3          9
# 34            14.0            2            0            3          3
# 35            24.0            1            2            4          2
# 36            43.0            3            1            4          7
# 37             9.0            4            3            2          8
# 38            12.0            0            0            2          1
# 41             3.0            2            1            0          4
# 42            11.0            0            0            2          2
# 43             8.0            0            0            1          1
# 45             5.0            1            0            1          3
# 48            14.0            3            3            3          8
# 50            20.0            1            2            3          2
# 51             8.0            4            4            1          8
# 53            11.0            0            1            2          2
# 54            29.0            2            3            4          4
# 58             3.0            2            1            0          4
# 59             1.0            4            4            0          8
# 60            25.0            3            1            4          6
# 61            11.0            0            0            2          2
# 62             8.0            0            0            1          1
# 64             5.0            1            0            1          3
# 67            14.0            3            3            3          8
# 69            20.0            1            2            3          2
# 70             8.0            4            4            1          8
# 72            11.0            0            1            2          2
# 73            29.0            2            3            4          4
# 75             5.0            2            2            1          4
# 76            16.0            3            4            3          6
# 78            17.0            0            1            3          1
# 79             3.0            3            2            0          6
# 80            24.0            2            3            4          5
# 81             2.0            3            3            0          6
# 82            33.0            0            1            4          4
# 83             2.0            4            4            0          8
# 84            41.0            0            2            4          1
# 85             9.0            3            4            2          7
# 87            13.0            3            4            3          7
#
#    pScore_rnd sScore_rnd
# 2           4          3
# 3           8          1
# 4           4          2
# 5           3          1
# 6           2          8
# 8           2          5
# 11          6          1
# 13          4          2
# 14          8          8
# 16          3          1
# 17          7          2
# 20          9          2
# 21          2          2
# 23          8          8
# 24          7          2
# 27          4          1
# 28          4          1
# 30          7          1
# 34          2          1
# 35          4          2
# 36          3          4
# 37          7          9
# 38          2          1
# 41          4          3
# 42          3          1
# 43          2          8
# 45          2          5
# 48          6          1
# 50          4          2
# 51          8          8
# 53          3          1
# 54          7          2
# 58          4          3
# 59          8          1
# 60          4          2
# 61          3          1
# 62          2          8
# 64          2          5
# 67          6          1
# 69          4          2
# 70          8          8
# 72          3          1
# 73          7          2
# 75          4          5
# 76          8          1
# 78          3          1
# 79          5          3
# 80          7          2
# 81          6          2
# 82          3          3
# 83          8          2
# 84          5          4
# 85          8          9
# 87          8          1

# %%
df_final.to_csv(r'/Users/mimiyufanyou/Documents/GitHub/rotten_movies/data/movie_final/final'+str(today)+'.csv', sep=',', index_label='id')

# %%
filepath = r'/Users/mimiyufanyou/Documents/GitHub/rotten_movies/data/movie_final/*.csv'
df_final = pd.concat([pd.read_csv(f) for f in glob.glob(filepath)], ignore_index = True)
